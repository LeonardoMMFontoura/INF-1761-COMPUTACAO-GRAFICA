# %% [markdown]
# <h1> Trabalho 1 </h1>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# <h2> Leitura das informações </h2>

# %%
#usei os arquivos no mesma pasta onde salvei o meu ipy
path = ""
cie_file = path + "all_1nm_data.xls"
macbeth_file = path  + "ColorChecker_RGB_and_spectra.xls"
planilha = "spectral_data"
#print(cie_file,macbeth_file)

# %%
cie = pd.read_excel(cie_file,header=3)
cie
# Out:
#       nm       CIE A   CIE D65  VM(l)  V'(l)     x bar         y bar  z bar  \
# 0    300    0.930483   0.03410    NaN    NaN       NaN           NaN    NaN
# 1    301    0.967643   0.36014    NaN    NaN       NaN           NaN    NaN
# 2    302    1.005970   0.68618    NaN    NaN       NaN           NaN    NaN
# 3    303    1.045490   1.01222    NaN    NaN       NaN           NaN    NaN
# 4    304    1.086230   1.33826    NaN    NaN       NaN           NaN    NaN
# ..   ...         ...       ...    ...    ...       ...           ...    ...
# 526  826  260.217000  59.16370    NaN    NaN  0.000002  5.980895e-07    0.0
# 527  827  260.567000  59.45090    NaN    NaN  0.000002  5.575746e-07    0.0
# 528  828  260.914000  59.73810    NaN    NaN  0.000001  5.198080e-07    0.0
# 529  829  261.259000  60.02530    NaN    NaN  0.000001  4.846123e-07    0.0
# 530  830  261.602000  60.31250    NaN    NaN  0.000001  4.518100e-07    0.0
#
#       x bar.1       y bar.1  z bar.1
# 0         NaN           NaN      NaN
# 1         NaN           NaN      NaN
# 2         NaN           NaN      NaN
# 3         NaN           NaN      NaN
# 4         NaN           NaN      NaN
# ..        ...           ...      ...
# 526  0.000002  7.946400e-07      NaN
# 527  0.000002  7.497800e-07      NaN
# 528  0.000002  7.074400e-07      NaN
# 529  0.000002  6.674800e-07      NaN
# 530  0.000002  6.297000e-07      NaN
#
# [531 rows x 11 columns]

# %%
#passando do data frame para numpy array
nm = cie['nm'].to_numpy(dtype=np.int)
Aw = cie['CIE A'].to_numpy(dtype=np.float32)
D65 = cie['CIE D65'].to_numpy(dtype=np.float32)
V = cie['VM(l)'].to_numpy(dtype=np.float32)
xbar = cie["x bar"].to_numpy(dtype=np.float32)
ybar = cie["y bar"].to_numpy(dtype=np.float32)
zbar = cie["z bar"].to_numpy(dtype=np.float32)

# %%
# selecionar a parte que interessa (lambda de 380 a 780)
mask = (nm>379)&(nm<781)
nm = nm[mask]
Aw = Aw[mask]
D65 = D65[mask]
V  = V[mask]
xbar = xbar[mask]
ybar = ybar[mask]
zbar= zbar[mask]

Aw = Aw/np.amax(Aw)
D65 = D65/np.amax(D65)

# %%
plt.plot(nm,Aw,"m")
plt.plot(nm,D65,"c")
plt.plot(nm,V,"--")
plt.plot(nm,xbar,"b")
plt.plot(nm,ybar,"g")
plt.plot(nm,zbar,"r")
plt.xlim(380, 780)
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(nm,Aw,"red")
plt.plot(nm,D65,"blue")
plt.plot(nm,V,"black")
plt.show()

# %%
# %%
nm_10 = nm[mask]
Aw_10 = Aw[mask]
D65_10 = D65[mask]
xbar_10 = xbar[mask]
ybar_10 = ybar[mask]
zbar_10 =  zbar[mask]

# %%
#plt.plot(nm_10,D65_10,'k--')
plt.plot(nm_10,D65_10* beta_green,'g')
plt.plot(nm_10,D65_10* beta_cian,'c')
plt.xlim(380, 731)
plt.show()

# %%
def beta2XYZ(Lw, beta,x_,y_,z_):
    k = 1/np.sum(Lw * y_)
    X = k * np.sum(Lw* beta * x_)
    Y = k * np.sum(Lw* beta * y_)
    Z = k * np.sum(Lw* beta * z_)
    return np.array([X,Y,Z])

XYZ_green = beta2XYZ(D65_10, beta_green,xbar[mask],ybar[mask],zbar[mask])
print(XYZ_green)
# Out:
# [0.14531483 0.23340117 0.09790131]

# %%
import skimage.color as sc
Lab_green = sc.xyz2lab(XYZ_green, illuminant='D65', observer='2')
print(Lab_green)
# Out:
# [ 55.42095702 -40.4905476   33.53996665]

# %%
XYZ_cian = beta2XYZ(D65_10, beta_cian,xbar[mask],ybar[mask],zbar[mask])
Lab_cian = sc.xyz2lab(XYZ_cian, illuminant='D65', observer='2')
print(Lab_cian)
# Out:
# [ 51.6183847  -24.10756678 -25.70953849]

# %%
def gamma_sRGB(x):
    t = x if x>0 else -x
    if t>0.0031308:
        gamma = 1.055*pow(t,1.0/2.4)-0.055
    else:
        gamma = 12.92*t
    return gamma if x>0 else -gamma
def XYZTosRGB(XYZ):
    M1 = np.array([[ 3.2404542, -1.5371385, -0.4985314],
                   [-0.9692660,  1.8760108,  0.0415560],
                   [ 0.0556434, -0.2040256,  1.0572252]])
    sRGB = np.dot(M1,XYZ)
    sRGB[0] = gamma_sRGB(sRGB[0])
    sRGB[1] = gamma_sRGB(sRGB[1])
    sRGB[2] = gamma_sRGB(sRGB[2])
    return sRGB

# %%
sRGB_green = XYZTosRGB(XYZ_green)
print(sRGB_green)
sRGB_cian = XYZTosRGB(XYZ_cian)
print(sRGB_cian)
# Out:
# [0.2790902 0.5847912 0.2805381]
# [-0.1866621   0.53416846  0.65168038]

# %%
beta_spec = np.zeros(D65.shape,dtype=np.float)
beta_spec[0] = 1

XYZ_spec = np.zeros(shape=(D65.shape[0],3),dtype=np.float)
sRGB_spec = np.zeros(shape=(D65.shape[0],3),dtype=np.float) 
for i in range(D65.shape[0]):
    beta = np.roll(beta_spec,i)
    XYZ_spec[i,:]= beta2XYZ(D65, beta,xbar,ybar,zbar)
    soma = XYZ_spec[i,0]+XYZ_spec[i,1]+XYZ_spec[i,2]
    if(soma > 0):
        x = XYZ_spec[i,0]/soma
        y = XYZ_spec[i,1]/soma
        Y = 1
        X = x*(Y/y)
        Z = (1-x-y)*(Y/y)
        sRGB_spec[i,:] = sc.xyz2rgb(np.array([X,Y,Z]))

# %%
ones = np.ones(nm.shape,dtype=np.float)
plt.scatter(nm,ones,color=sRGB_spec)
plt.show()
